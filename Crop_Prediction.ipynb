# %% [markdown]
# <a href="https://colab.research.google.com/github/zennyMe17/GoogleCollab/blob/main/Crop_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
raw_data = pd.read_csv('/content/sample_data/crop_dataset.csv')
raw_data.head()
# Out:
#    Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0         26.0      52.0      38.0     Sandy      Maize        37          0
# 1         29.0      52.0      45.0     Loamy  Sugarcane        12          0
# 2         34.0      65.0      62.0     Black     Cotton         7          9
# 3         32.0      62.0      34.0       Red    Tobacco        22          0
# 4         28.0      54.0      46.0    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temparature      8000 non-null   float64
#  1   Humidity         8000 non-null   float64
#  2   Moisture         8000 non-null   float64
#  3   Soil Type        8000 non-null   object
#  4   Crop Type        8000 non-null   object
#  5   Nitrogen         8000 non-null   int64
#  6   Potassium        8000 non-null   int64
#  7   Phosphorous      8000 non-null   int64
#  8   Fertilizer Name  8000 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 562.6+ KB

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Assuming the raw data is in a DataFrame called `df`
# Split the data into train and test, with a 85-15 ratio (you can adjust this as needed)
train_df, test_df = train_test_split(raw_data, test_size=0.15, random_state=42)

# Now, split the train_df into training and validation (e.g., 85-15 for training and validation)
train_df, val_df = train_test_split(train_df, test_size=0.15, random_state=42)

# Check the shape of the resulting splits
print("Training DataFrame shape:", train_df.shape)
print("Validation DataFrame shape:", val_df.shape)
print("Test DataFrame shape:", test_df.shape)
# Out:
# Training DataFrame shape: (5780, 9)
# Validation DataFrame shape: (1020, 9)
# Test DataFrame shape: (1200, 9)

# %%
input_cols = list(train_df.columns) # Finding all cols That is parameter

# %%
input_cols.remove('Crop Type')
input_cols.remove('Fertilizer Name')# Finding output

# %%
train_inputs = train_df[input_cols]
train_targets1 = train_df['Crop Type']
train_targets2 = train_df['Fertilizer Name']

# %%
train_inputs.head()
# Out:
#       Temparature  Humidity  Moisture Soil Type  Nitrogen  Potassium  \
# 7629        30.64     48.22     36.77     Sandy        18          1
# 6200        29.01     58.63     70.00       Red         4          0
# 1201        27.27     42.20     47.49     Loamy        10         16
# 3219        31.73     54.97     64.26     Black         7          6
# 4320        31.48     59.28     37.95     Black        23          1
#
#       Phosphorous
# 7629           25
# 6200            6
# 1201           18
# 3219           32
# 4320           25

# %%
val_inputs = val_df[input_cols]
val_targets1 = val_df['Crop Type']
val_targets2 = val_df['Fertilizer Name']

# %%
test_inputs = test_df[input_cols]
test_targets1 = test_df['Crop Type']
test_targets2 = test_df['Fertilizer Name']

# %%
categorocal_cols = train_inputs.select_dtypes(include='object').columns.tolist()

# %%
numeric_cols = train_inputs.select_dtypes(include=np.number).columns.tolist()

# %%
numeric_cols
# Out:
# ['Temparature', 'Humidity', 'Moisture', 'Nitrogen', 'Potassium', 'Phosphorous']

# %%
categorocal_cols
# Out:
# ['Soil Type']

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean').fit(train_inputs[numeric_cols])

# %%
train_inputs[numeric_cols] = imputer.transform(train_inputs[numeric_cols])
# Out:
# <ipython-input-93-cf3d98818259>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
val_inputs[numeric_cols] = imputer.transform(val_inputs[numeric_cols])
# Out:
# <ipython-input-94-f5ed44bae973>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_inputs[numeric_cols] = imputer.transform(test_inputs[numeric_cols])
# Out:
# <ipython-input-95-653370f6beca>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler().fit(train_inputs[numeric_cols])
train_inputs[numeric_cols] = scaler.transform(train_inputs[numeric_cols])
test_inputs[numeric_cols] = scaler.transform(test_inputs[numeric_cols])
val_inputs[numeric_cols] = scaler.transform(val_inputs[numeric_cols])
# Out:
# <ipython-input-96-d30c44951be0>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-96-d30c44951be0>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-96-d30c44951be0>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False,handle_unknown='ignore').fit(test_inputs[categorocal_cols])
encoded_cols = list(encoder.get_feature_names_out(categorocal_cols))

# %%
encoded_cols
# Out:
# ['Soil Type_Black',
#  'Soil Type_Clayey',
#  'Soil Type_Loamy',
#  'Soil Type_Red',
#  'Soil Type_Sandy']

# %%
train_inputs[encoded_cols] = encoder.transform(train_inputs[categorocal_cols])
# Out:
# <ipython-input-99-d74bb6fb4e8e>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
val_inputs[encoded_cols] = encoder.transform(val_inputs[categorocal_cols])
test_inputs[encoded_cols] = encoder.transform(test_inputs[categorocal_cols])
# Out:
# <ipython-input-100-3a7f1b2e0ed7>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-100-3a7f1b2e0ed7>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_inputs
# Out:
#       Temparature  Humidity  Moisture Soil Type  Nitrogen  Potassium  \
# 7629       0.5320  0.205103    0.3354     Sandy  0.391304   0.043478
# 6200       0.4505  0.465483    1.0000       Red  0.086957   0.000000
# 1201       0.3635  0.054527    0.5498     Loamy  0.217391   0.695652
# 3219       0.5865  0.373937    0.8852     Black  0.152174   0.260870
# 4320       0.5740  0.481741    0.3590     Black  0.500000   0.043478
# ...           ...       ...       ...       ...       ...        ...
# 1206       0.7785  0.766383    0.4006     Black  0.913043   0.000000
# 2106       0.7690  0.396198    0.4496     Sandy  0.260870   0.347826
# 3156       0.9020  0.408704    0.6080     Loamy  0.282609   0.130435
# 2935       0.7180  0.508254    0.3616    Clayey  0.369565   0.130435
# 4487       0.4615  0.767384    0.6824     Sandy  0.913043   0.130435
#
#       Phosphorous  Soil Type_Black  Soil Type_Clayey  Soil Type_Loamy  \
# ...

# %%
train_inputs.to_csv('train_inputs.csv',index=False)
val_inputs.to_csv('val_inputs.csv',index=False)
test_inputs.to_csv('test_inputs.csv',index=False)

# %%
test_inputs.head()
# Out:
#       Temparature  Humidity  Moisture Soil Type  Nitrogen  Potassium  \
# 2215       0.7625  0.330165    0.4148     Sandy  0.282609   0.173913
# 2582       0.8930  0.531266    0.5582     Loamy  0.326087   0.608696
# 1662       0.6575  0.462981    0.2458     Loamy  0.065217   0.304348
# 3027       0.6840  0.696598    0.3138    Clayey  0.217391   0.000000
# 4343       0.3785  0.185343    0.3774       Red  0.456522   0.000000
#
#       Phosphorous  Soil Type_Black  Soil Type_Clayey  Soil Type_Loamy  \
# 2215     0.869565              0.0               0.0              0.0
# 2582     0.304348              0.0               0.0              1.0
# 1662     0.739130              0.0               0.0              1.0
# 3027     0.673913              0.0               1.0              0.0
# 4343     0.413043              0.0               0.0              0.0
#
#       Soil Type_Red  Soil Type_Sandy
# 2215            0.0              1.0
# 2582            0.0              0.0
# ...

# %%
x_train = train_inputs[numeric_cols+encoded_cols]
x_val = val_inputs[numeric_cols+encoded_cols]
x_test = test_inputs[numeric_cols+encoded_cols]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=42)

# %%
model.fit(x_train,train_targets1)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
train_preds = model.predict(x_train)

# %%
accuracy_score(train_targets1,train_preds)
# Out:
# 1.0

# %%
train_probs = model.predict_proba(x_train)

# %%
model.score(x_val,val_targets)
# Out:
# 0.09411764705882353

# %%
model.score(x_test,test_targets)
# Out:
# 0.09083333333333334

# %%
from sklearn.tree import plot_tree,export_text

# %%
text_representation = export_text(model,feature_names=list(x_train.columns),max_depth=2)

# %%
print(text_representation)
# Out:
# |--- Moisture <= 0.57
# |   |--- Temparature <= 0.29
# |   |   |--- Phosphorous <= 0.60
# |   |   |   |--- truncated branch of depth 23
# |   |   |--- Phosphorous >  0.60
# |   |   |   |--- truncated branch of depth 16
# |   |--- Temparature >  0.29
# |   |   |--- Potassium <= 0.20
# |   |   |   |--- truncated branch of depth 34
# |   |   |--- Potassium >  0.20
# |   |   |   |--- truncated branch of depth 23
# |--- Moisture >  0.57
# |   |--- Moisture <= 0.57
# |   |   |--- Humidity <= 0.67
# |   |   |   |--- truncated branch of depth 5
# |   |   |--- Humidity >  0.67
# |   |   |   |--- class: Cotton
# |   |--- Moisture >  0.57
# |   |   |--- Humidity <= 0.90
# |   |   |   |--- truncated branch of depth 34
# |   |   |--- Humidity >  0.90
# |   |   |   |--- truncated branch of depth 7

# %%
x_train.columns
# Out:
# Index(['Temparature', 'Humidity', 'Moisture', 'Nitrogen', 'Potassium',
#        'Phosphorous', 'Soil Type_Black', 'Soil Type_Clayey', 'Soil Type_Loamy',
#        'Soil Type_Red', 'Soil Type_Sandy', 'Fertilizer Name_10-26-26',
#        'Fertilizer Name_14-35-14', 'Fertilizer Name_17-17-17',
#        'Fertilizer Name_20-20', 'Fertilizer Name_28-28', 'Fertilizer Name_DAP',
#        'Fertilizer Name_Urea'],
#       dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.17334203, 0.15445608, 0.15903794, 0.11142724, 0.0740032 ,
#        0.1020513 , 0.02040805, 0.0220507 , 0.02452387, 0.01902782,
#        0.01977331, 0.02481248, 0.0180173 , 0.01680939, 0.01493052,
#        0.0157996 , 0.01306486, 0.01646429])

# %%
importance_df = pd.DataFrame({'feature':x_train.columns,'importance':model.feature_importances_}).sort_values('importance',ascending=False)

# %%
importance_df.head(10)
# Out:
#                      feature  importance
# 0                Temparature    0.173342
# 2                   Moisture    0.159038
# 1                   Humidity    0.154456
# 3                   Nitrogen    0.111427
# 5                Phosphorous    0.102051
# 4                  Potassium    0.074003
# 11  Fertilizer Name_10-26-26    0.024812
# 8            Soil Type_Loamy    0.024524
# 7           Soil Type_Clayey    0.022051
# 6            Soil Type_Black    0.020408

# %%
px.bar(importance_df.head(15),x='feature',y='importance',color='feature')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model = DecisionTreeClassifier(random_state=42,max_depth=21)

# %%
model.fit(x_train,train_targets)
# Out:
# DecisionTreeClassifier(max_depth=21, random_state=42)

# %%
model.score(x_train,train_targets)
# Out:
# 0.7780276816608996

# %%
model.score(x_val,val_targets)
# Out:
# 0.08431372549019608

# %%
def max_dept_error(md):
  model = DecisionTreeClassifier(random_state=42,max_depth=md)
  model.fit(x_train,train_targets)
  train_error = 1 - model.score(x_train,train_targets)
  val_error = 1 - model.score(x_val,val_targets)
  return train_error,val_error

# %%
errors_df = pd.DataFrame([max_dept_error(md) for md in range(1,20)],columns=['train_error','val_error'])

# %%
errors_df.sort_values('val_error')
# Out:
#     train_error  val_error
# 13     0.574221   0.897059
# 18     0.314533   0.902941
# 7      0.808997   0.904902
# 8      0.782180   0.905882
# 16     0.419377   0.907843
# 17     0.365917   0.907843
# 6      0.831315   0.907843
# 11     0.668858   0.909804
# 14     0.524048   0.909804
# 12     0.623356   0.909804
# 2      0.885813   0.911765
# 0      0.895848   0.912745
# 5      0.847232   0.912745
# 1      0.889100   0.914706
# 9      0.748097   0.914706
# 3      0.876471   0.918627
# 4      0.864706   0.919608
# 10     0.710900   0.923529
# 15     0.472491   0.923529

# %%
px.line(errors_df,x=errors_df.index,y=['train_error','val_error'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model = DecisionTreeClassifier(random_state=42,max_leaf_nodes=974)

# %%
model.fit(x_train,train_targets)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=974, random_state=42)

# %%
model.score(x_train,train_targets)
# Out:
# 0.5031141868512111

# %%
model.score(x_val,val_targets)
# Out:
# 0.0803921568627451

# %%
def max_leaf_nodes_error(mln):
  model = DecisionTreeClassifier(random_state=42,max_leaf_nodes=pow(2,mln))
  model.fit(x_train,train_targets)
  train_error = 1 - model.score(x_train,train_targets)
  val_error = 1 - model.score(x_val,val_targets)
  return train_error,val_error

# %%
max_leaf_nodes_errors_df = pd.DataFrame([max_leaf_nodes_error(mln) for mln in range(2,10)],columns=['train_error','val_error'])

# %%
max_leaf_nodes_errors_df
# Out:
#    train_error  val_error
# 0     0.889100   0.914706
# 1     0.885121   0.912745
# 2     0.876125   0.913725
# 3     0.869377   0.914706
# 4     0.852941   0.912745
# 5     0.826817   0.910784
# 6     0.758304   0.904902
# 7     0.652595   0.909804

# %%
max_leaf_nodes_errors_df.index = (max_leaf_nodes_errors_df.index+2)**2

# %%
max_leaf_nodes_errors_df
# Out:
#     train_error  val_error
# 4      0.889100   0.914706
# 9      0.885121   0.912745
# 16     0.876125   0.913725
# 25     0.869377   0.914706
# 36     0.852941   0.912745
# 49     0.826817   0.910784
# 64     0.758304   0.904902
# 81     0.652595   0.909804

# %%
max_leaf_nodes_errors_df.sort_values('val_error')
# Out:
#     train_error  val_error
# 64     0.758304   0.904902
# 81     0.652595   0.909804
# 49     0.826817   0.910784
# 9      0.885121   0.912745
# 36     0.852941   0.912745
# 16     0.876125   0.913725
# 25     0.869377   0.914706
# 4      0.889100   0.914706

# %%
model = DecisionTreeClassifier(random_state=42,max_leaf_nodes=984,max_depth=96)

# %%
model.fit(x_train,train_targets)
# Out:
# DecisionTreeClassifier(max_depth=96, max_leaf_nodes=984, random_state=42)

# %%
model.score(x_train,train_targets)
# Out:
# 0.5058823529411764

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_jobs=-1,random_state=42)

# %%
model.fit(x_train,train_targets)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
model.predict_proba(x_train)
# Out:
# array([[0.07, 0.06, 0.65, ..., 0.01, 0.01, 0.07],
#        [0.01, 0.03, 0.07, ..., 0.  , 0.66, 0.06],
#        [0.1 , 0.03, 0.02, ..., 0.02, 0.08, 0.65],
#        ...,
#        [0.01, 0.  , 0.01, ..., 0.06, 0.05, 0.75],
#        [0.07, 0.02, 0.01, ..., 0.02, 0.05, 0.72],
#        [0.01, 0.02, 0.06, ..., 0.03, 0.06, 0.04]])

# %%
len(model.estimators_)
# Out:
# 100

# %%
model.predict(x_train)
# Out:
# array(['Ground Nuts', 'Tobacco', 'Wheat', ..., 'Wheat', 'Wheat', 'Maize'],
#       dtype=object)

# %%
x_train
# Out:
#       Temparature  Humidity  Moisture  Nitrogen  Potassium  Phosphorous  \
# 7629       0.5320  0.205103    0.3354  0.391304   0.043478     0.543478
# 6200       0.4505  0.465483    1.0000  0.086957   0.000000     0.130435
# 1201       0.3635  0.054527    0.5498  0.217391   0.695652     0.391304
# 3219       0.5865  0.373937    0.8852  0.152174   0.260870     0.695652
# 4320       0.5740  0.481741    0.3590  0.500000   0.043478     0.543478
# ...           ...       ...       ...       ...        ...          ...
# 1206       0.7785  0.766383    0.4006  0.913043   0.000000     0.000000
# 2106       0.7690  0.396198    0.4496  0.260870   0.347826     0.239130
# 3156       0.9020  0.408704    0.6080  0.282609   0.130435     0.934783
# 2935       0.7180  0.508254    0.3616  0.369565   0.130435     0.478261
# 4487       0.4615  0.767384    0.6824  0.913043   0.130435     0.000000
#
#       Soil Type_Black  Soil Type_Clayey  Soil Type_Loamy  Soil Type_Red  \
# ...

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5780 entries, 7629 to 4487
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Temparature               5780 non-null   float64
#  1   Humidity                  5780 non-null   float64
#  2   Moisture                  5780 non-null   float64
#  3   Nitrogen                  5780 non-null   float64
#  4   Potassium                 5780 non-null   float64
#  5   Phosphorous               5780 non-null   float64
#  6   Soil Type_Black           5780 non-null   float64
#  7   Soil Type_Clayey          5780 non-null   float64
#  8   Soil Type_Loamy           5780 non-null   float64
#  9   Soil Type_Red             5780 non-null   float64
#  10  Soil Type_Sandy           5780 non-null   float64
#  11  Fertilizer Name_10-26-26  5780 non-null   float64
#  12  Fertilizer Name_14-35-14  5780 non-null   float64
# ...

# %%
# Assuming `model` is your trained model, and `scaler` is the MinMaxScaler you used during training
import pandas as pd

# Assuming 'new_data' is the new input data you want to make predictions on
new_data = pd.DataFrame({
    'Temparature': [26],
    'Humidity': [52],
    'Moisture': [38],
    'Nitrogen': [37],
    'Potassium': [0],
    'Phosphorous': [0],
    'Soil Type_Black': [0],
    'Soil Type_Clayey': [0],
    'Soil Type_Loamy': [0],  # Example: Loamy soil type
    'Soil Type_Red': [0],
    'Soil Type_Sandy': [1],
    'Fertilizer Name_10-26-26': [0],  # Example: 10-26-26 fertilizer
    'Fertilizer Name_14-35-14': [0],
    'Fertilizer Name_17-17-17': [0],
    'Fertilizer Name_20-20': [0],
    'Fertilizer Name_28-28': [0],
    'Fertilizer Name_DAP': [0],
    'Fertilizer Name_Urea': [1]
})

# Step 1: Scale the new input data using the same scaler used for the training data


# Step 2: Make predictions using your trained model
predictions = model.predict(new_data)

# Step 3: Output the predictions
print(predictions)
# Out:
# ['Oil seeds']

# %%
# Assuming `model` is your trained model, and `scaler` is the MinMaxScaler you used during training
import pandas as pd
import requests

# Function to estimate moisture based on humidity
def estimate_moisture(humidity):
    if humidity > 80:
        return 70
    elif humidity > 60:
        return 60
    elif humidity > 40:
        return 50
    elif humidity > 20:
        return 40
    else:
        return 30

# Replace with your actual WeatherAPI key and location
API_KEY = 'c8038b38b6be4e6c9a540208251505'
LOCATION = 'Goa'

# Fetching weather data from WeatherAPI
def get_weather(api_key, location):
    url = f"https://api.weatherapi.com/v1/current.json?key={api_key}&q={location}"
    response = requests.get(url)
    data = response.json()
    temp = data['current']['temp_c']
    humidity = data['current']['humidity']
    return temp, humidity

# Get weather data (temperature and humidity)
temperature, humidity = get_weather(API_KEY, LOCATION)

# Estimate soil moisture based on humidity
moisture = estimate_moisture(humidity)

# User inputs for Nitrogen, Potassium, Phosphorous, Soil Type, and Fertilizer
nitrogen = int(input("Enter nitrogen value: "))
potassium = int(input("Enter potassium value: "))
phosphorous = int(input("Enter phosphorous value: "))

soil_types = ['Black', 'Clayey', 'Loamy', 'Red', 'Sandy']
fertilizers = ['10-26-26', '14-35-14', '17-17-17', '20-20', '28-28', 'DAP', 'Urea']

print("\nSelect Soil Type:")
for i, s in enumerate(soil_types): print(f"{i}: {s}")
soil_choice = int(input("Enter number for soil type: "))
selected_soil = soil_types[soil_choice]

print("\nSelect Fertilizer Name:")
for i, f in enumerate(fertilizers): print(f"{i}: {f}")
fertilizer_choice = int(input("Enter number for fertilizer: "))
selected_fertilizer = fertilizers[fertilizer_choice]

# One-hot encode soil and fertilizer types
soil_encoded = [1 if soil == selected_soil else 0 for soil in soil_types]
fertilizer_encoded = [1 if fert == selected_fertilizer else 0 for fert in fertilizers]

# Prepare the new input data for prediction
new_data = pd.DataFrame({
    'Temparature': [temperature],
    'Humidity': [humidity],
    'Moisture': [moisture],
    'Nitrogen': [nitrogen],
    'Potassium': [potassium],
    'Phosphorous': [phosphorous],
    **{f'Soil Type_{soil}': [val] for soil, val in zip(soil_types, soil_encoded)},
    **{f'Fertilizer Name_{fert}': [val] for fert, val in zip(fertilizers, fertilizer_encoded)}
})

# Step 1: Scale the new input data using the same scaler used for the training data
# Assuming you have a pre-trained scaler from MinMaxScaler
# from joblib import load
# scaler = load('your_scaler.pkl')
# scaled_data = scaler.transform(new_data)

# Step 2: Make predictions using your trained model
# Assuming `model` is your trained model
# model = load('your_model.pkl')
# predictions = model.predict(scaled_data)

# For now, let's print the input data
print("\nPrepared Input Data:")
print(new_data)

# Uncomment below when model and scaler are available
# print("\nPrediction Result:", predictions)
# Out:
# Enter nitrogen value: 100
# Enter potassium value: 100
# Enter phosphorous value: 100
#
# Select Soil Type:
# 0: Black
# 1: Clayey
# 2: Loamy
# 3: Red
# 4: Sandy
# Enter number for soil type: 0
#
# Select Fertilizer Name:
# 0: 10-26-26
# 1: 14-35-14
# 2: 17-17-17
# 3: 20-20
# 4: 28-28
# 5: DAP
# 6: Urea
# Enter number for fertilizer: 1
#
# Prepared Input Data:
#    Temparature  Humidity  Moisture  Nitrogen  Potassium  Phosphorous  \
# 0         28.8        68        60       100        100          100
#
#    Soil Type_Black  Soil Type_Clayey  Soil Type_Loamy  Soil Type_Red  \
# 0                1                 0                0              0
#
#    Soil Type_Sandy  Fertilizer Name_10-26-26  Fertilizer Name_14-35-14  \
# 0                0                         0                         1
#
#    Fertilizer Name_17-17-17  Fertilizer Name_20-20  Fertilizer Name_28-28  \
# 0                         0                      0                      0
#
# ...

# %%
# Step 1: Scale the new input data using the same scaler used for the training data


# Step 2: Make predictions using your trained model
predictions = model.predict(new_data)

# Step 3: Output the predictions
print(predictions)
# Out:
# ['Oil seeds']
